# %%
import os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/gpfs/space/home/joonas97'

# %%
ct = nib.load("/gpfs/space/home/joonas97/data/kits21/kits21/data/case_00000/imaging.nii.gz")

# %%
ct_data = ct.get_fdata()

# %%
plt.imshow(ct_data[200], cmap='gray')

# %%
plt.imshow(ct_data[205], cmap='gray')

# %%
lits_file = "/Users/joonasariva/Documents/PHD/lits17/Training Batch 2/segmentation-28.nii"
lits_img = "/Users/joonasariva/Documents/PHD/lits17/Training Batch 2/volume-28.nii"

# %%
lits_seg = nib.load(lits_file).get_fdata()
lits_data = nib.load(lits_img).get_fdata()

# %%
lits_seg.shape
# Out:
# (512, 512, 129)

# %%
plt.imshow(lits_seg[:,:,70], cmap = 'gray')

# %%
plt.imshow(lits_data[:,:,70], cmap = 'gray')

# %%
lits_data.shape
# Out:
# (512, 512, 129)
